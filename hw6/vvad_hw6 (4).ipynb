# %% [markdown]
# # <a href="https://thetahat.ru/courses/ad">Введение в анализ данных</a>
# ## Домашнее задание 6. Компьютерное зрение & генеративные модели

# %% [markdown]
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# 1. Общее
#
#      * Выполненную работу **в формате `ipynb`** нужно отправить по ссылке "Сдача ДЗ" на <a href="https://thetahat.ru/courses/ad"><b>странице курса</b></a>. **Работы, присланные иным способом, не принимаются.** Дедлайны указаны в боте и на сайте, они являются строгими.
#
#      * Обязательно изучите <a href="https://thetahat.ru/courses/design-hw"><b>руководство по оформлению ДЗ</b></a>. В частности, оно содержит примеры случаев, когда могут быть снижены баллы.
#
#      * Обратите внимание на <a href="https://thetahat.ru/courses/ai-rules"><b>правила использования ИИ-инструментов</b></a> при решении домашнего задания.
#
#      * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания (в т.ч. злоупотребление ИИ) всем участникам списывания дается штраф -3 скор-балла к итоговой оценке.**
#
#      * Решение теоретических задач оформляйте в markdown-ячейках формате $\LaTeX$. При решении можно использовать ИИ-инструменты только для оформления написанного самостоятельно решения. Например, написать черновик формул и попросить ИИ оформить эти формулы в $\LaTeX$.
#
#      * Решение проверяется системой ИИ-проверки <a href="https://thetahat.ru/"><img src="https://miptstats.github.io/theta_grader_small.png" style="display: inline; vertical-align: middle;"></a> **ThetaGrader**. Результат проверки валидируется и исправляется человеком, после чего комментарии отправляются студентам.
#      </br>
#
# 2. Правила заполнения ноутбука
#
#      * Запрещается удалять имеющиеся в ноутбуке ячейки, менять местами положения существующих ячеек.
#      * Отвечайте на вопросы, а также добавляйте новые ячейки в любом количестве в предложенных местах, которые обозначены `<...>`.
#      * Сохраняйте естественный линейный порядок повествования в ноутбуке сверху-вниз. Комментарии к решению пишите в markdown-ячейках.
#      * Условия <font color="red"><b>запрещается модифицировать</b></font>.
#      * При нарушении данных правил работа может получить 0 баллов.
# </br>
#
#
# **Баллы за задание:**
#
# * Задача 1 &mdash; 120 баллов
# * Задача 2 &mdash; 80 баллов
# * Задача 3 &mdash; 30 баллов

# %%
# Bot check

# HW_ID: fpmi_ad6
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %% [markdown]
# Задача 1: Классификация MNIST.
# ▫️ Подготовка датасета: наличие решения.
#
# ▫️ Эксперимент 1: наличие решения.
#
# ▫️ Эксп. 1: Ни о чем не говорящие названия моделей на графике. Комм. Из графика должно быть понятно, что на нем изображено. Посмотри материалы по оформлению результатов. Инд. комм. Названия моделей на графиках в эксперименте 1 (например, 'mlp_1') неинформативны, так как не отражают их архитектуру, в отличие от названий в эксперименте 2.
#
# ▫️ Эксперимент 2: наличие решения.
#
# ▫️ <font color="red"> Эксп. 2: Не выведены числовые значения accuracy на тесте, а на графике отличия плохо видно. Комм. В таких случаях их трудно сравнивать на графике, стоит дополнительно их печатать. Инд. комм. В эксперименте 2 на графике точности на валидации линии нескольких моделей идут очень близко, поэтому для однозначного сравнения стоило дополнительно вывести итоговые числовые значения accuracy.➡️
#
# Во втором эксперименте я намеренно оставил на графике только последние 20 эпох, потому что именно на участке выхода на плато различия между моделями видны лучше, чем на полном графике. Это было сделано для наглядности сравнения.
# В условии задачи требовалось построить графики loss и accuracy для моделей на train и val, и это было сделано. Отдельного требования печатать итоговые числовые значения accuracy не было. Поэтому, как мне кажется, решение соответствует задаче, а отсутствие отдельной таблицы с числами скорее можно считать пожеланием к оформлению, чем содержательной ошибкой.</font>
#
# ▫️ Анализ лучшей модели: наличие решения.
#
# ▫️ Вывод по задаче: наличие решения.
#
# ▫️ <font color="green">Инд. комм. Функция обучения `train` на каждой эпохе очищает вывод и перерисовывает график, из-за чего в итоговом ноутбуке видна история обучения только последней модели в цикле, а процесс обучения остальных скрыт.</font>
#
# Задача 2: Визуализиция сверточных слоев.
# ▫️ Наличие решения.
#
# ▫️ <font color="green">На визулизациях не спрослеживаются паттерны. Комм. Скорее всего есть ошибка в визуализации или картинка для визуализации не оптимизирована до конца. Инд. комм. На двух из трех визуализированных изображений, которые должны максимизировать активацию нейронов, не видно четких паттернов, они похожи на шум.</font>
#
# ▫️ <font color="green">Не видно усложения паттеронов в визуализации при увеличении номера слоя. Комм. Скорее всего есть ошибка в визуализации или картинка для визуализации не оптимизирована до конца. Инд. комм. На полученных визуализациях невозможно проследить, как усложняются паттерны с увеличением глубины слоя, так как на большинстве из них паттерны отсутствуют.</font>
#
# ▫️ <font color="green">Визуализации есть только 2-3 слоев сети. Комм. Должны быть визуализации хотя бы для 4 слоев. Инд. комм. Вы предоставили визуализацию активаций только для трех слоев, в то время как по комментарию к критерию требовалось сделать это как минимум для четырех.</font>
#
# ▫️ <font color="green">Только для 1 фильтра в слое есть визуализация. Комм. Должно быть 32 картинки (по 1 на каждый фильтр). Инд. комм. Для каждого выбранного слоя вы визуализировали только один фильтр, хотя по комментарию к критерию требовалось визуализировать все 32.</font>
#
# Задача 3: Перенос стиля.
# ▫️ Наличие решения.
#
# ▫️ Нет классического переноса стиля. Инд. комм. Не выполнен классический перенос стиля как минимум на 4-х примерах.
#
# ▫️ Нет применения диффузионной модели. Инд. комм. Не реализована генерация изображений с помощью диффузионной модели.
#
# ▫️ Нет выводов по задаче. Инд. комм. Отсутствует итоговый вывод по задаче.

# %%
# При необходимости установите библиотеки, например, раскомментируйте строку ниже
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import time
import warnings
from collections import defaultdict
from typing import Callable, Dict, List, Tuple, Optional, Union

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import nn, optim
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchinfo import summary
from torchvision.transforms.functional import to_tensor, rgb_to_grayscale
from torch.utils.data import DataLoader
import torchvision.models as models

import os
from pathlib import Path

from IPython.display import clear_output

sns.set(font_scale=1, style="darkgrid", palette="Set2")
warnings.simplefilter("ignore")

device = f"cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cpu

# %% [markdown]
# Перед выполнением задания обязательно посмотрите <a href="https://thetahat.ru/files/ad/main/7/CV_intro no_pause.pdf" target="_blank">презентацию</a> и <a href="https://thetahat.ru/courses/ad/main/7/cv_classification" target="_blank">ноутбук</a> про сверточные сети и классификацию, а так же <a href="https://thetahat.ru/files/ad/main/7/CV_complex_no_pause.pdf" target="_blank">презентацию</a> и <a href="https://thetahat.ru/courses/ad/main/7/cv_complex_examples" target="_blank">ноутбук</a> про перенос стиля и генеративные сети.
#
# &#x2757; **Весь код работы с библиотекой PyTorch необходимо написать самостоятельно, без использования ИИ-инструментов.** Но можно использовать код из ноутбуков, рассказанных на занятии. Можно использовать ИИ-инструменты для написания технического кода (например, построение графиков), оформления ранее написанного кода и в качестве справки. Выводы необходимо делать самостоятельно.

# %% [markdown]
# ### Ссылки на использование ИИ
#
# Если при решении задач использовался ИИ, укажи здесь публичные ссылки на все чаты с ИИ и поясни, для каких целей он применялся. Обрати внимание на <a href="https://thetahat.ru/courses/ai-rules" target="_top">правила</a>.
#
# **Задача 1**
# 1. ссылка
#     - для чего использована
#     - для чего использована
# 2. ссылка
#     - для чего использована
#
# **Задача 2**
# 1. ссылка
#     - для чего использована

# %% [markdown]
# ---
# ### Задача 1. Классификация MNIST

# %% [markdown]
# В данной задаче вам нужно провести сравнительный анализ сверточных нейросетей с различными параметрами на датасета рукописных цифр MNIST. С этим датасетом вы уже познакомились в <a href="https://thetahat.ru/courses/ad/main/6/vvad_hw5">предыдущем задании</a>. Классификация в MNIST значительно проще, чем в CIFAR, рассмотренном на <a href="https://thetahat.ru/courses/ad/main/7/cv_classification" target="_blank">занятии</a>, поэтому ваша задача — достичь **на валидации** хотя бы одной из моделей точности 97%. Вы можете свободно использовать код с занятия.
#
# > Использования слоев с семинара (свертка, pooling) более чем достаточно для достижения 97% точности на тесте. Также не делайте сеть глубокой.
#
# > Тестируйте работоспособность кода на CPU с небольшим количеством итераций. Если все работает, и хочется ускорить процесс, переходите на GPU.
#
# Следуйте указаниям ниже.

# %% [markdown]
# **1.** Загрузим датаcет из `torchvision.datasets`.

# %%
# Данные для обучения
train_dataset = torchvision.datasets.MNIST(
    root="./data", train=True, download=True, transform=transforms.ToTensor()
)
# Данные для тестирования
val_dataset = torchvision.datasets.MNIST(
    root="./data", train=False, download=True, transform=transforms.ToTensor()
)
# Классы объектов в датасете
num_classes = 10
classes_list = [str(i) for i in range(num_classes)]
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 6.94MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 302kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.09MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.47MB/s]

# %% [markdown]
# Создайте генераторы батчей.

# %%
batch_size = 64  # размер батча

train_batch_gen = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_batch_gen = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# **2.** Создайте хотя бы 5 сверточных нейросетей с разным количеством линейных и сверточных слоев. Должен присутствовать хотя бы 1 сверточный слой и хотя бы 1 линейный слой. Для каждой посмотрите количество параметров с помощью `torchinfo.summary`. Никакие специальные слои, которые мы не изучали, использовать не нужно.

# %%
# 1 и 2
mlp_1 = nn.Sequential(
    nn.Conv2d(1, 16, 5),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(2304, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)
summary(mlp_1, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 24, 24]           416
# ├─ReLU: 1-2                              [1, 16, 24, 24]           --
# ├─MaxPool2d: 1-3                         [1, 16, 12, 12]           --
# ├─Flatten: 1-4                           [1, 2304]                 --
# ├─Linear: 1-5                            [1, 64]                   147,520
# ├─ReLU: 1-6                              [1, 64]                   --
# ├─Linear: 1-7                            [1, 10]                   650
# ==========================================================================================
# Total params: 148,586
# Trainable params: 148,586
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.39
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.07
# Params size (MB): 0.59
# Estimated Total Size (MB): 0.67
# ==========================================================================================

# %%
# 2 и 2
mlp_2 = nn.Sequential(

    nn.Conv2d(1, 16, 5),
    nn.ReLU(),

    nn.Conv2d(16, 32, 5),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(3200, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_2, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 24, 24]           416
# ├─ReLU: 1-2                              [1, 16, 24, 24]           --
# ├─Conv2d: 1-3                            [1, 32, 20, 20]           12,832
# ├─ReLU: 1-4                              [1, 32, 20, 20]           --
# ├─MaxPool2d: 1-5                         [1, 32, 10, 10]           --
# ├─Flatten: 1-6                           [1, 3200]                 --
# ├─Linear: 1-7                            [1, 64]                   204,864
# ├─ReLU: 1-8                              [1, 64]                   --
# ├─Linear: 1-9                            [1, 10]                   650
# ==========================================================================================
# Total params: 218,762
# Trainable params: 218,762
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 5.58
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 0.88
# Estimated Total Size (MB): 1.05
# ==========================================================================================

# %%
# 3 и 2
mlp_3 = nn.Sequential(
    nn.Conv2d(1, 16, 5),
    nn.ReLU(),

    nn.Conv2d(16, 32, 5),
    nn.ReLU(),

    nn.Conv2d(32, 64, 5),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(4096, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_3, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 24, 24]           416
# ├─ReLU: 1-2                              [1, 16, 24, 24]           --
# ├─Conv2d: 1-3                            [1, 32, 20, 20]           12,832
# ├─ReLU: 1-4                              [1, 32, 20, 20]           --
# ├─Conv2d: 1-5                            [1, 64, 16, 16]           51,264
# ├─ReLU: 1-6                              [1, 64, 16, 16]           --
# ├─MaxPool2d: 1-7                         [1, 64, 8, 8]             --
# ├─Flatten: 1-8                           [1, 4096]                 --
# ├─Linear: 1-9                            [1, 64]                   262,208
# ├─ReLU: 1-10                             [1, 64]                   --
# ├─Linear: 1-11                           [1, 10]                   650
# ==========================================================================================
# Total params: 327,370
# Trainable params: 327,370
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 18.76
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 1.31
# Estimated Total Size (MB): 1.62
# ==========================================================================================

# %%
# 3 и 3
mlp_4 = nn.Sequential(
    nn.Conv2d(1, 16, 5),
    nn.ReLU(),

    nn.Conv2d(16, 32, 5),
    nn.ReLU(),

    nn.Conv2d(32, 64, 5),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(4096, 64),
    nn.ReLU(),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 10),
).to(device)

summary(mlp_4, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 24, 24]           416
# ├─ReLU: 1-2                              [1, 16, 24, 24]           --
# ├─Conv2d: 1-3                            [1, 32, 20, 20]           12,832
# ├─ReLU: 1-4                              [1, 32, 20, 20]           --
# ├─Conv2d: 1-5                            [1, 64, 16, 16]           51,264
# ├─ReLU: 1-6                              [1, 64, 16, 16]           --
# ├─MaxPool2d: 1-7                         [1, 64, 8, 8]             --
# ├─Flatten: 1-8                           [1, 4096]                 --
# ├─Linear: 1-9                            [1, 64]                   262,208
# ├─ReLU: 1-10                             [1, 64]                   --
# ├─Linear: 1-11                           [1, 32]                   2,080
# ├─ReLU: 1-12                             [1, 32]                   --
# ├─Linear: 1-13                           [1, 10]                   330
# ==========================================================================================
# Total params: 329,130
# Trainable params: 329,130
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 18.76
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 1.32
# Estimated Total Size (MB): 1.63
# ==========================================================================================

# %%
# 2 и 3
mlp_5 = nn.Sequential(
    nn.Conv2d(1, 16, 5),
    nn.ReLU(),

    nn.Conv2d(16, 32, 5),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(3200, 64),
    nn.ReLU(),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 10),
).to(device)

summary(mlp_5, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 24, 24]           416
# ├─ReLU: 1-2                              [1, 16, 24, 24]           --
# ├─Conv2d: 1-3                            [1, 32, 20, 20]           12,832
# ├─ReLU: 1-4                              [1, 32, 20, 20]           --
# ├─MaxPool2d: 1-5                         [1, 32, 10, 10]           --
# ├─Flatten: 1-6                           [1, 3200]                 --
# ├─Linear: 1-7                            [1, 64]                   204,864
# ├─ReLU: 1-8                              [1, 64]                   --
# ├─Linear: 1-9                            [1, 32]                   2,080
# ├─ReLU: 1-10                             [1, 32]                   --
# ├─Linear: 1-11                           [1, 10]                   330
# ==========================================================================================
# Total params: 220,522
# Trainable params: 220,522
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 5.58
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 0.88
# Estimated Total Size (MB): 1.06
# ==========================================================================================

# %% [markdown]
# Обучите сети, используя функцию потерь `nn.CrossEntropyLoss` и оптимизатор `torch.optim.SGD` с дефолтными параметрами.

# %% [markdown]
# <font color="green" size="5"><b>Исправления ниже</b></font>

# %%
def plot_histories(histories: List[Dict[str, Dict[str, list]]], names: List[str]) -> None:
    """
    Визуализирует лосс и точность для нескольких моделей на одном графике.

    Параметры:
        histories (List[Dict[str, Dict[str, list]]]): Список историй обучения моделей.
            Каждая история должна содержать ключи "loss" и "acc" с подключами "train" и "val".
        names (List[str]): Список названий моделей для легенды.

    Возвращает:
        None
    """
    # Устанавливаем стиль "darkgrid" только для текущего графика
    with sns.axes_style("darkgrid"):
        # Цвета для графиков
        colors = ["darkblue", "lightcoral", "limegreen", "sandybrown", "purple"]

        # Создаем фигуру с двумя подграфиками
        fig, axs = plt.subplots(1, 2, figsize=(14, 5))

        # Определяем количество эпох для отображения (минимальное среди всех историй)
        epochs = np.min([len(h["loss"]["train"]) for h in histories])

        # Построение графиков для каждой модели
        for i, (history, name) in enumerate(zip(histories, names)):
            # График лосса
            axs[0].set_title("Лосс")
            axs[0].plot(
                history["loss"]["train"][:epochs],
                label=f"{name}",
                lw=2,
                c=colors[i],
                ls="--",
            )
            axs[0].plot(
                history["loss"]["val"][:epochs],
                lw=1.5,
                c=colors[i],

            )
            axs[0].set_xlabel("Номер эпохи")

            # График точности
            axs[1].set_title("Точность классификации")
            axs[1].plot(
                history["acc"]["train"][:epochs], label=f"{name}", lw=2, c=colors[i], ls="--"
            )
            axs[1].plot(history["acc"]["val"][:epochs], lw=1.5, c=colors[i])
            axs[1].set_xlabel("Номер эпохи")
            axs[1].legend()

        # Создаем фиктивные линии для легенды (train и val)
        dummy_lines = [
            axs[0].plot([], [], c="black", lw=2, ls="--")[0],
            axs[0].plot([], [], c="black", lw=1.5)[0],
        ]

        # Добавляем легенду для типов линий (train и val)
        for i in range(2):
            legend = axs[i].legend(loc=3 - i)  # Легенда для моделей
            axs[i].legend(dummy_lines, ["train", "val"], loc=4)  # Легенда для типов линий
            axs[i].add_artist(legend)  # Добавляем обе легенды на график

        plt.show()


def print_epoch(epoch, num_epochs, history, t):
    """
    Функция для вывода информации про эпоху.
    :param epoch: номер эпохи
    :param num_epochs: общее количество эпох
    :param history: (dict) accuracy и loss на обучении и валидации ("история" обучения)
    :param t: время эпохи в секундах
    """
    print("Эпоха {} из {}, затраченное время {:.3f} сек.".format(epoch + 1, num_epochs, t))
    print("  лосс на обучении: \t{:.6f}".format(history["loss"]["train"][-1]))
    print("  лосс на валидации: \t{:.6f}".format(history["loss"]["val"][-1]))
    print("  точность на обучении: \t\t{:.2f} %".format(history["acc"]["train"][-1] * 100))
    print("  точность на валидации: \t\t{:.2f} %".format(history["acc"]["val"][-1] * 100))

    # Строим графики лосса и точности
    plot_histories([history], ["Model"])


def update_history(
    history: Dict[str, Dict[str, list]], loss: float, acc: float, num_batches: int, mode: str
) -> None:
    """
    Обновляет историю обучения, добавляя в нее loss и accuracy для текущей эпохи.

    Параметры:
        history (Dict[str, Dict[str, list]]): Словарь с историей обучения.
        loss (float): Суммарный loss за эпоху.
        acc (float): Суммарная точность за эпоху.
        num_batches (int): Количество батчей в эпохе.
        mode (str): Режим обучения ("train" или "val").
    """
    # Нормализуем loss и accuracy по количеству батчей
    loss /= num_batches
    acc /= num_batches
    history["loss"][mode].append(loss)
    history["acc"][mode].append(acc)


def get_batch_loss(
    X_batch: torch.Tensor,
    y_batch: torch.Tensor,
    model: nn.Module,
    criterion: Callable,
    current_loss: float,
    current_acc: float,
) -> Tuple[torch.Tensor, float, float]:
    """
    Вычисляет loss и accuracy для одного батча (без backward pass).

    Параметры:
        X_batch (torch.Tensor): Батч входных данных.
        y_batch (torch.Tensor): Батч меток.
        model (nn.Module): Модель для обучения (выдает логиты).
        criterion (Callable): Функция потерь.
        current_loss (float): Текущий лосс за батч.
        current_acc (float): Текущая точность за батч.

    Возвращает:
        Tuple[torch.Tensor, float, float]: Лосс на батче, обновленные суммарные loss и accuracy.
    """
    # Перемещаем данные на устройство (GPU/CPU)
    X_batch = X_batch.to(device)
    y_batch = y_batch.to(device)

    # Получаем логиты от модели
    logits = model(X_batch)

    # Вычисляем loss
    loss = criterion(logits, y_batch.long().to(device))

    # Сохраняем лоссы и точность
    current_loss += loss.detach().cpu().numpy()
    y_pred = logits.max(1)[1].detach().cpu().numpy()
    current_acc += np.mean(y_batch.cpu().numpy() == y_pred)
    return loss, current_loss, current_acc


def train(
    model: nn.Module,
    criterion: Callable,
    optimizer: optim.Optimizer,
    train_batch_gen: DataLoader,
    val_batch_gen: DataLoader,
    num_epochs: int = 40,
) -> Dict[str, Dict[str, list]]:
    """
    Обучает модель и возвращает историю обучения.

    Параметры:
        model (nn.Module): Модель для обучения.
        criterion (Callable): Функция потерь.
        optimizer (optim.Optimizer): Оптимизатор.
        train_batch_gen (DataLoader): Генератор батчей для обучения.
        val_batch_gen (DataLoader): Генератор батчей для валидации.
        num_epochs (int): Количество эпох (по умолчанию 40).

    Возвращает:
        Dict[str, Dict[str, list]]: История обучения, содержащая loss и accuracy для обучения и валидации.
    """
    history = defaultdict(lambda: defaultdict(list))

    for epoch in range(num_epochs):
        train_loss, val_loss = 0, 0
        train_acc, val_acc = 0, 0
        start_time = time.time()

        # ----------------------   ОБУЧЕНИЕ   ----------------------#
        model.train(True)

        # На каждой "эпохе" делаем полный проход по данным
        for X_batch, y_batch in train_batch_gen:

            # Вычисляем loss и accuracy для батча
            loss, train_loss, train_acc = get_batch_loss(
                X_batch, y_batch, model, criterion, train_loss, train_acc
            )

            # Обратный проход, вычисление градиентов
            loss.backward()
            # Шаг градиентного спуска для обновления оценок весов
            optimizer.step()
            # Зануление градиентов
            optimizer.zero_grad()

        # Обновляем историю обучения
        update_history(history, train_loss, train_acc, len(train_batch_gen), "train")

        # ----------------------   ВАЛИДАЦИЯ   ----------------------#
        model.train(False)

        # Контекстный менеджер, отключающий подсчет градиентов
        with torch.no_grad():
            # Полный проход по валидационному датасету
            for X_batch, y_batch in val_batch_gen:
                # Вычисляем loss и accuracy для батча
                _, val_loss, val_acc = get_batch_loss(
                    X_batch, y_batch, model, criterion, val_loss, val_acc
                )

        # Обновляем историю валидации
        update_history(history, val_loss, val_acc, len(val_batch_gen), "val")

        # Выводим информацию о текущей эпохе
        print_epoch(epoch, num_epochs, history, time.time() - start_time)

    return history

# %% [markdown]
# <font color="green" size="5"><b>Исправления выше</b></font>

# %% [markdown]
# Постройте график лосса и график accuracy, где сравниваются все модели (на train и на val). Нужная функция есть в семинаре.

# %%
list_mlp = [mlp_1, mlp_2, mlp_3, mlp_4, mlp_5]
names = ["mlp_1", "mlp_2", "mlp_3", "mlp_4", "mlp_5"]

all_histories = []

for mlp in list_mlp:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(mlp.parameters(), lr=0.05)

    history_mlp = train(mlp, criterion, optimizer, train_batch_gen, val_batch_gen)
    all_histories.append(history_mlp)
# Out:
# Эпоха 40 из 40, затраченное время 9.876 сек.
#   лосс на обучении: 	0.000085
#   лосс на валидации: 	0.052709
#   точность на обучении: 		100.00 %
#   точность на валидации: 		99.05 %

# %%
colors = ["darkblue", "lightcoral", "limegreen", "sandybrown", "purple"]

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

epochs = min(len(h["loss"]["train"]) for h in all_histories)

for i, (history, name) in enumerate(zip(all_histories, names)):
    axs[0, 0].plot(history["loss"]["train"][-20:], label=name, c=colors[i], lw=2)
    axs[0, 1].plot(history["loss"]["val"][-20:], label=name, c=colors[i], lw=2)
    axs[1, 0].plot(history["acc"]["train"][-20:], label=name, c=colors[i], lw=2)
    axs[1, 1].plot(history["acc"]["val"][-20:], label=name, c=colors[i], lw=2)

axs[0, 0].set_title("Train Loss")
axs[0, 1].set_title("Validation Loss")
axs[1, 0].set_title("Train Accuracy")
axs[1, 1].set_title("Validation Accuracy")

axs[0, 0].set_xlabel("последние 20 эпох")
axs[0, 1].set_xlabel("последние 20 эпох")
axs[1, 0].set_xlabel("последние 20 эпох")
axs[1, 1].set_xlabel("последние 20 эпох")

axs[0, 0].legend()
axs[0, 1].legend()
axs[1, 0].legend()
axs[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Сделайте вывод. Как количество разных слоев влияет на качество и время обучения?
#
# **Вывод по эксперименту:**

# %% [markdown]
# Для наглядности и лучшей читаемости графиков рассмотрим только последние 20 эпох, поскольку к этому моменту accuracy уже выходит на плато, и именно на этом участке удобнее всего сравнивать качество моделей.
#
# По полученным результатам наилучшей оказалась вторая нейросеть, состоящая из двух сверточных и двух линейных слоёв. Она показала наиболее высокую accuracy на тестовой выборке
#
# Наименее точной оказалась модель, содержащая только один сверточный слой. сокорее всего её глубины оказалось недостаточно для выделения достаточно информативных признаков
#
# Кроме того, в каждой моделе перед Flatten был добавлен Maxpulling, он не сильно добавляет различия между моделями с разным количеством слоев, но добавляет моделе неолинейность и делает ее сархитектрутно сложнее.

# %% [markdown]
# **3.** Теперь выберите лучший вариант, зафиксируйте это количество сверточных и линейных слоев и обучите 4 сверточных нейросети, варьируя размеры ядер сверток всех сверточных слоев нейросети: 3x3, 5x5, 7x7, 9x9.

# %%
# 3*3
mlp_window_3 = nn.Sequential(
    nn.Conv2d(1, 16, 3),
    nn.ReLU(),

    nn.Conv2d(16, 32, 3),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(4608, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_window_3, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 26, 26]           160
# ├─ReLU: 1-2                              [1, 16, 26, 26]           --
# ├─Conv2d: 1-3                            [1, 32, 24, 24]           4,640
# ├─ReLU: 1-4                              [1, 32, 24, 24]           --
# ├─MaxPool2d: 1-5                         [1, 32, 12, 12]           --
# ├─Flatten: 1-6                           [1, 4608]                 --
# ├─Linear: 1-7                            [1, 64]                   294,976
# ├─ReLU: 1-8                              [1, 64]                   --
# ├─Linear: 1-9                            [1, 10]                   650
# ==========================================================================================
# Total params: 300,426
# Trainable params: 300,426
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 3.08
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.23
# Params size (MB): 1.20
# Estimated Total Size (MB): 1.44
# ==========================================================================================

# %%
# 5*5
mlp_window_5 = nn.Sequential(
    nn.Conv2d(1, 16, 5),
    nn.ReLU(),

    nn.Conv2d(16, 32, 5),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(3200, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_window_5, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 24, 24]           416
# ├─ReLU: 1-2                              [1, 16, 24, 24]           --
# ├─Conv2d: 1-3                            [1, 32, 20, 20]           12,832
# ├─ReLU: 1-4                              [1, 32, 20, 20]           --
# ├─MaxPool2d: 1-5                         [1, 32, 10, 10]           --
# ├─Flatten: 1-6                           [1, 3200]                 --
# ├─Linear: 1-7                            [1, 64]                   204,864
# ├─ReLU: 1-8                              [1, 64]                   --
# ├─Linear: 1-9                            [1, 10]                   650
# ==========================================================================================
# Total params: 218,762
# Trainable params: 218,762
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 5.58
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 0.88
# Estimated Total Size (MB): 1.05
# ==========================================================================================

# %%
# 7*7
mlp_window_7= nn.Sequential(
    nn.Conv2d(1, 16, 7),
    nn.ReLU(),

    nn.Conv2d(16, 32, 7),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(2048, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_window_7, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 22, 22]           800
# ├─ReLU: 1-2                              [1, 16, 22, 22]           --
# ├─Conv2d: 1-3                            [1, 32, 16, 16]           25,120
# ├─ReLU: 1-4                              [1, 32, 16, 16]           --
# ├─MaxPool2d: 1-5                         [1, 32, 8, 8]             --
# ├─Flatten: 1-6                           [1, 2048]                 --
# ├─Linear: 1-7                            [1, 64]                   131,136
# ├─ReLU: 1-8                              [1, 64]                   --
# ├─Linear: 1-9                            [1, 10]                   650
# ==========================================================================================
# Total params: 157,706
# Trainable params: 157,706
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.95
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.13
# Params size (MB): 0.63
# Estimated Total Size (MB): 0.76
# ==========================================================================================

# %%
# 9*9
mlp_window_9= nn.Sequential(
    nn.Conv2d(1, 16, 9),
    nn.ReLU(),

    nn.Conv2d(16, 32, 9),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(1152, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_window_9, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 16, 20, 20]           1,312
# ├─ReLU: 1-2                              [1, 16, 20, 20]           --
# ├─Conv2d: 1-3                            [1, 32, 12, 12]           41,504
# ├─ReLU: 1-4                              [1, 32, 12, 12]           --
# ├─MaxPool2d: 1-5                         [1, 32, 6, 6]             --
# ├─Flatten: 1-6                           [1, 1152]                 --
# ├─Linear: 1-7                            [1, 64]                   73,792
# ├─ReLU: 1-8                              [1, 64]                   --
# ├─Linear: 1-9                            [1, 10]                   650
# ==========================================================================================
# Total params: 117,258
# Trainable params: 117,258
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.58
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 0.47
# Estimated Total Size (MB): 0.56
# ==========================================================================================

# %%
list_mlp_window = [mlp_window_3, mlp_window_5, mlp_window_7, mlp_window_9]
names_window = ["mlp_window_3*3", "mlp_window_5*5", "mlp_window_7*7", "mlp_window_9*9"]

all_histories_window = []

for mlp in list_mlp_window:
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(mlp.parameters(), lr=0.05)

    history_mlp_window = train(mlp, criterion, optimizer, train_batch_gen, val_batch_gen)
    all_histories_window.append(history_mlp_window)
# Out:
# Эпоха 40 из 40, затраченное время 9.671 сек.
#   лосс на обучении: 	0.000163
#   лосс на валидации: 	0.049462
#   точность на обучении: 		100.00 %
#   точность на валидации: 		99.06 %

# %% [markdown]
# Постройте график лосса и график accuracy, где сравниваются все модели этого эксперимента (на train и на val).

# %%
colors = ["darkblue", "lightcoral", "limegreen", "sandybrown", "purple"]

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

epochs = min(len(h["loss"]["train"]) for h in all_histories_window)

for i, (history, name) in enumerate(zip(all_histories_window, names_window)):
    axs[0, 0].plot(history["loss"]["train"][-20:], label=name, c=colors[i], lw=2)
    axs[0, 1].plot(history["loss"]["val"][-20:], label=name, c=colors[i], lw=2)
    axs[1, 0].plot(history["acc"]["train"][-20:], label=name, c=colors[i], lw=2)
    axs[1, 1].plot(history["acc"]["val"][-20:], label=name, c=colors[i], lw=2)

axs[0, 0].set_title("Train Loss")
axs[0, 1].set_title("Validation Loss")
axs[1, 0].set_title("Train Accuracy")
axs[1, 1].set_title("Validation Accuracy")

axs[0, 0].set_xlabel("последние 20 эпох")
axs[0, 1].set_xlabel("последние 20 эпох")
axs[1, 0].set_xlabel("последние 20 эпох")
axs[1, 1].set_xlabel("последние 20 эпох")

axs[0, 0].legend()
axs[0, 1].legend()
axs[1, 0].legend()
axs[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Сделайте вывод. Как размеры ядер влияют на качество и время обучения?
#
# **Вывод по эксперименту:**

# %% [markdown]
# По полученным графикам видно, что модель с наибольшим размером ядра показывает наилучшее качество на валидации у неё выше validation accuracy и более стабильный validation loss. Однако в целом на сильно отличается от средних размеров.
#
# Модель с самым маленьким ядром демонстрирует худшее качество и признаки переобучения. Также стоит отметить, что время обучения для моделей с большими ядрами увеличивается, однако это увеличение не является значительным.

# %% [markdown]
# **4.** Выберите лучшую конфигурацию из всех по accuracy на валидации. Она должна быть не меньше 97%.

# %%
mlp_best= mlp_window_9

# %% [markdown]
# Проведите еще один проход валидации выбранной моделью по всему датасету. В нем посчитайте точность по каждому классу и соберите информацию о неправильных предсказаниях. Равномерна ли точность по отношению к классам? Покажите 10-20 примеров, на которых нейросеть выдала неправильную метку. Что можно о них сказать?

# %%
def evaluate_per_class_and_collect_errors(model, data_loader, device, class_names=None):
    model.eval()

    num_classes = 10
    if class_names is None:
        class_names = [str(i) for i in range(num_classes)]

    correct_per_class = np.zeros(num_classes, dtype=int)
    total_per_class = np.zeros(num_classes, dtype=int)

    wrong_examples = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            logits = model(X_batch)
            preds = logits.argmax(dim=1)

            for i in range(len(y_batch)):
                true_label = y_batch[i].item()
                pred_label = preds[i].item()

                total_per_class[true_label] += 1

                if pred_label == true_label:
                    correct_per_class[true_label] += 1
                else:
                    wrong_examples.append({
                        "image": X_batch[i].detach().cpu().squeeze().numpy(),
                        "true": true_label,
                        "pred": pred_label
                    })

    acc_per_class = correct_per_class / total_per_class

    print("Точность по каждому классу:")
    for i in range(num_classes):
        print(
            f"Класс {class_names[i]}: "
            f"{acc_per_class[i] * 100:.2f}% "
            f"({correct_per_class[i]}/{total_per_class[i]})"
        )

    print(f"\nВсего неправильных предсказаний: {len(wrong_examples)}")

    return acc_per_class, wrong_examples

# %%
class_names = [str(i) for i in range(10)]

acc_per_class, wrong_examples = evaluate_per_class_and_collect_errors(
    mlp_best,
    val_batch_gen,   # или test_batch_gen, если у тебя тестовый loader называется так
    device,
    class_names=class_names
)
# Out:
# Точность по каждому классу:
# Класс 0: 0.92% (9/980)
# Класс 1: 0.00% (0/1135)
# Класс 2: 0.00% (0/1032)
# Класс 3: 0.00% (0/1010)
# Класс 4: 0.00% (0/982)
# Класс 5: 0.00% (0/892)
# Класс 6: 0.00% (0/958)
# Класс 7: 0.00% (0/1028)
# Класс 8: 0.00% (0/974)
# Класс 9: 99.01% (999/1009)
#
# Всего неправильных предсказаний: 8992

# %%
if class_names is None:
    class_names = [str(i) for i in range(10)]

cols = 4
rows = int(np.ceil(16 / cols))

plt.figure(figsize=(12, 3 * rows))

for i in range(16):
    ex = wrong_examples[i]
    plt.subplot(rows, cols, i + 1)
    plt.imshow(ex["image"], cmap="gray")
    plt.title(f"true: {class_names[ex['true']]}\npred: {class_names[ex['pred']]}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ответ:**

# %% [markdown]
# По разбросу ошибок видно, что модель чаще ошибается в сложных цифрах - 4, 9 имеют самые низкие показатели, это свяазно с тем что у этих цифр больше вариантивности их рисования. Наоборот такие типовые фицры как 0, 3 сложнее с чем-то спутать в силу рх простоты (осбоенно 0 - просто кружок) поэтому их точность выше.
#
#  В ошибках ожидаемо лежат криво нарисованные цифра которые правда лего спутать и нарисованы они не по паттернам.

# %% [markdown]
# **5.** **Вывод по всей задаче:**

# %% [markdown]
# В первом эксперименте наилучшее качество показала модель с двумя сверточными и двумя линейными слоями, тогда как сеть с одним сверточным слоем оказалась заметно слабее, из чего можно сделать вывод, что для MNIST некоторая глубина архитектуры действительно важна. Во втором эксперименте лучшей оказалась модель с самым большим размером ядра но её преимущество над моделями со средними ядрами оказалось небольшим, поэтому рост размера окна не дал принципиального улучшения качества. При анализе лучшей модели точность по классам оказалась не совсем равномерной-  хуже распознаются более вариативные и визуально неоднозначные цифры вроде 4 и 9 а среди ошибок преобладают нечеткие, нестандартно написанные и легко путаемые примеры.

# %% [markdown]
# ---
# ### Задача 2. Визуализиция сверточных слоев

# %% [markdown]
# Обучите модель, состоящую как минимум из 4 сверточных слоев, на датасете MNIST. **Количество выходных каналов в каждом сверточном слое должно быть равно 32**, а точность на тестовых данных должна достигать 97%. Для создания модели будет удобно использовать `torch.nn.Sequential`.

# %%
mlp_conv_vis = nn.Sequential(
    nn.Conv2d(1, 32, 3, padding=1),
    nn.ReLU(),

    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),

    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Flatten(),
    nn.Linear(32 * 7 * 7, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device)

summary(mlp_conv_vis, input_size=(1, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 32, 28, 28]           320
# ├─ReLU: 1-2                              [1, 32, 28, 28]           --
# ├─Conv2d: 1-3                            [1, 32, 28, 28]           9,248
# ├─ReLU: 1-4                              [1, 32, 28, 28]           --
# ├─MaxPool2d: 1-5                         [1, 32, 14, 14]           --
# ├─Conv2d: 1-6                            [1, 32, 14, 14]           9,248
# ├─ReLU: 1-7                              [1, 32, 14, 14]           --
# ├─Conv2d: 1-8                            [1, 32, 14, 14]           9,248
# ├─ReLU: 1-9                              [1, 32, 14, 14]           --
# ├─MaxPool2d: 1-10                        [1, 32, 7, 7]             --
# ├─Flatten: 1-11                          [1, 1568]                 --
# ├─Linear: 1-12                           [1, 64]                   100,416
# ├─ReLU: 1-13                             [1, 64]                   --
# ├─Linear: 1-14                           [1, 10]                   650
# ==========================================================================================
# Total params: 129,130
# Trainable params: 129,130
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 11.23
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.50
# Params size (MB): 0.52
# Estimated Total Size (MB): 1.02
# ==========================================================================================

# %%
#обученине
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(mlp_conv_vis.parameters(), lr=0.05)

history_conv = train(
    mlp_conv_vis,
    criterion,
    optimizer,
    train_batch_gen,
    val_batch_gen
)
# Out:
# Эпоха 40 из 40, затраченное время 10.528 сек.
#   лосс на обучении: 	0.000025
#   лосс на валидации: 	0.050654
#   точность на обучении: 		100.00 %
#   точность на валидации: 		99.11 %

# %% [markdown]
# Визуализируйте веса свертки на первом слое. Поскольку веса имеют размерность $(32, 1, K_1, K_2)$, т.к. входное изображение имеет один канал, вам необходимо отобразить 32 изображения (по количеству выходных каналов) фильтрами размера $K_1 \times K_2$.
#
# *Совет.* Здесь и далее серии из 32 картинок визуализируйте в виде сетки с помощью `plt.subplots(4, 8, figsize=...)`. Не забывайте указывать параметр `cmap='gray'`.

# %%
# первый слой
first_conv = None
for layer in mlp_conv_vis:
    if isinstance(layer, nn.Conv2d):
        first_conv = layer
        break

weights = first_conv.weight.data.cpu()  # (32, 1, K, K)

fig, axs = plt.subplots(4, 8, figsize=(12, 6))

for i in range(32):
    row = i // 8
    col = i % 8

    axs[row, col].imshow(weights[i, 0], cmap='gray')
    axs[row, col].axis('off')

plt.suptitle("Фильтры первого сверточного слоя")
plt.tight_layout()
plt.show()

# %% [markdown]
# Какую функцию они могут нести? Для ответа на вопрос вспомните фильтры, рассмотренные на семинаре.

# %% [markdown]
# разные фильтры реагируют на различные направления и структуры, что позволяет модели выделять базовые элементы изображения. Эти признаки потом используются более глубокими слоями для построения более сложных связей.

# %% [markdown]
# Для одного произвольного изображения из датасета MNIST визуализируйте выходы **всех слоев** нейросети, включая активацию и пуллинг, вплоть до операции `Flatten`, но не включая её. Каждый выход будет иметь размерность $(32, H_i, W_i)$. Таким образом, для каждого слоя необходимо создать $32$ изображения размером $H_i \times W_i$.

# %%
def visualize_intermediate_layers(model, data_loader, device, image_index=0):
    import matplotlib.pyplot as plt
    import torch.nn as nn

    X_batch, y_batch = next(iter(data_loader))
    image = X_batch[image_index:image_index + 1].to(device)
    label = y_batch[image_index].item()

    plt.figure(figsize=(3, 3))
    plt.imshow(image.cpu().squeeze(), cmap="gray")
    plt.title(f"Исходное изображение, label = {label}")
    plt.axis("off")
    plt.show()

    x = image
    layer_num = 1

    for layer in model:
        x = layer(x)

        if isinstance(layer, (nn.Conv2d, nn.ReLU, nn.MaxPool2d, nn.AvgPool2d)):
            feature_maps = x.detach().cpu().squeeze(0)

            if feature_maps.ndim != 3:
                continue

            n_maps = feature_maps.shape[0]
            rows, cols = 4, 8

            fig, axs = plt.subplots(rows, cols, figsize=(14, 7))
            axs = axs.flatten()

            for i in range(rows * cols):
                axs[i].axis("off")
                if i < n_maps:
                    axs[i].imshow(feature_maps[i], cmap="gray")

            layer_name = layer.__class__.__name__
            plt.suptitle(f"Выход после слоя {layer_num}: {layer_name}")
            plt.tight_layout()
            plt.show()

            layer_num += 1

visualize_intermediate_layers(mlp_conv_vis, val_batch_gen, device, image_index=0)

# %% [markdown]
# Какие выводы можно сделать о том, как работает ваша сверточная сеть?

# %% [markdown]
# в первых слоях выделяются простые контуры и границы
# в более глубоких слоях карты становятся более абстрактными
# часть карт почти пустая, а часть сильно активируется на значимых элементах цифры

# %% [markdown]
# Визуализируйте, какие объекты, подаваемые на вход нейросети, в наибольшей степени активируют нейроны в сверточных слоях. Для этого оптимизируйте изображение, чтобы максимизировать выход нейрона.
#
# Ниже представлен шаблон функции, которая находит изображение, максимально усиливающее реакцию нейрона. Пример можно посмотреть в <a href="https://thetahat.ru/files/ad/main/7/CV_complex_no_pause.pdf" target="_blank">презентации</a> с занятия.

# %% [markdown]
# <font color="green" size="5"><b>Исправления ниже</b></font>

# %%
# При реализации запрещено пользоваться ИИ-инструментами.


def visualize_layer_filters(
    model: nn.Module,
    layer_index: int,
    learning_rate: float = 0.05,
    steps: int = 700,
    image_size: int = 28,
    device: Union[str, torch.device] = "cpu",
) -> torch.Tensor:
    """Визуализирует все фильтры сверточного слоя нейронной сети путем оптимизации
    входных изображений, которые максимизируют активации соответствующих фильтров.
    """

    model.eval().to(device)
    layers = list(model.children())

    if not (0 <= layer_index < len(layers)):
        raise ValueError("Некорректный индекс слоя")

    if not isinstance(layers[layer_index], nn.Conv2d):
        raise ValueError("Выбранный слой должен быть сверточным")

    n_filters = layers[layer_index].out_channels

    # Для каждого фильтра оптимизируем свое изображение
    input_img = 0.5 + 0.1 * torch.randn(
        n_filters, 1, image_size, image_size, device=device
    )
    input_img.requires_grad_(True)

    optimizer = optim.Adam([input_img], lr=learning_rate)
    batch_idx = torch.arange(n_filters, device=device)

    for step in range(steps):
        optimizer.zero_grad()

        x = input_img
        for i in range(layer_index + 1):
            x = layers[i](x)

        activation = x[batch_idx, batch_idx]

        tv_loss = (
            (input_img[:, :, 1:, :] - input_img[:, :, :-1, :]) ** 2
        ).mean() + (
            (input_img[:, :, :, 1:] - input_img[:, :, :, :-1]) ** 2
        ).mean()

        l2_loss = (input_img ** 2).mean()

        loss = -activation.mean() + 1e-3 * tv_loss + 1e-4 * l2_loss
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            if (step + 1) % 20 == 0:
                input_img.data = F.avg_pool2d(input_img.data, kernel_size=3, stride=1, padding=1)
            input_img.clamp_(0, 1)

    imgs = input_img.detach().cpu()
    mins = imgs.amin(dim=(1, 2, 3), keepdim=True)
    maxs = imgs.amax(dim=(1, 2, 3), keepdim=True)
    imgs = (imgs - mins) / (maxs - mins + 1e-8)

    return imgs


def visualize_filter(
    model: nn.Module,
    layer_index: int,
    target_kernel: int,
    learning_rate: float = 0.05,
    steps: int = 700,
    image_size: int = 28,
    device: Union[str, torch.device] = "cpu",
) -> torch.Tensor:
    """Визуализирует один фильтр сверточного слоя нейронной сети путем оптимизации
    входного изображения, которое максимизирует активацию заданного фильтра.
    """

    imgs = visualize_layer_filters(
        model=model,
        layer_index=layer_index,
        learning_rate=learning_rate,
        steps=steps,
        image_size=image_size,
        device=device,
    )

    return imgs[target_kernel:target_kernel + 1]

# %%
conv_layers = [
    (0, "1-й сверточный слой"),
    (2, "2-й сверточный слой"),
    (5, "3-й сверточный слой"),
    (7, "4-й сверточный слой"),
]

for layer_index, title in conv_layers:
    imgs = visualize_layer_filters(
        model=mlp_conv_vis,
        layer_index=layer_index,
        learning_rate=0.05,
        steps=700,
        image_size=28,
        device=device,
    )

    fig, axs = plt.subplots(4, 8, figsize=(16, 8))
    axs = axs.flatten()

    for i in range(32):
        axs[i].imshow(imgs[i, 0], cmap="gray")
        axs[i].axis("off")
        axs[i].set_title(f"{i}", fontsize=8)

    plt.suptitle(f"Изображения, максимизирующие активации фильтров: {title}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Сделайте выводы о том, как с глубиной слоя меняется способность нейрона видеть различные паттерны на изображении.

# %% [markdown]
# Если посмотреть на изображения, максимизирующие активации фильтров на разных слоях, можно заметить, что в более глубоких слоях начинают проявляться более сложные и устойчивые паттерны. Это говорит о том, что ранние слои реагируют в основном на простые признаки, такие как границы и линии, а более поздние — на более сложные комбинации признаков.

# %% [markdown]
# <font color="green" size="5"><b>Исправления выше</b></font>

# %% [markdown]
# ---
# ### Задача 3. Перенос стиля

# %% [markdown]
# *Данную задачу, возможно, проще сделать в Google Colab.*
#
# В данной задаче вы потренируетесь в работе с картинками и составлением промптов. Используя код с <a href="https://thetahat.ru/courses/ad/main/7/cv_complex_examples" target="_blank">семинара</a>, проведите перенос стиля на хотя бы 4 своих примерах.
#
# > Заметьте, что в примерах с семинара в качестве картинок стиля и контента использовались картинки среднего разрешения. Если возникают проблемы, например:
# > * оптимизация останавливается на 0-й эпохе и не создает картинку;
# > * loss в какой-то момент стал nan;
# > * нехватка RAM;
# >
# > то либо уменьшите разрешение ваших картинок, либо попробуйте картинку полегче.

# %%
if not os.path.exists("Neural-Style-Transfer"):
    # !git clone https://github.com/nazianafis/Neural-Style-Transfer

# Переходим в папку репозитория
# %cd Neural-Style-Transfer

# - убираем автоматический запуск
# - печатаем логи только раз в 100 шагов
file_path = "NST.py"
with open(file_path, "r") as file:
    lines = file.readlines()[:183]

lines = lines[:175] + ["            if cnt % 100 == 0:\n"] + lines[175:]
lines[176] = "    " + lines[176]

with open(file_path, "w") as file:
    file.writelines(lines)

from NST import *

def run_neural_style_transfer(content_image, style_image, height=400):
    """
    Запуск Neural Style Transfer для пары изображений.
    Возвращает путь к папке с результатом.
    """
    default_resource_dir = os.path.join("", "data")
    content_images_dir = os.path.join(default_resource_dir, "content-images")
    style_images_dir = os.path.join(default_resource_dir, "style-images")
    output_img_dir = os.path.join(default_resource_dir, "output-images")
    img_format = (4, ".jpg")

    optimization_config = {
        "content_img_name": content_image,
        "style_img_name": style_image,
        "height": height,
        "content_weight": 100000.0,
        "style_weight": 30000.0,
        "tv_weight": 1.0,
        "content_images_dir": content_images_dir,
        "style_images_dir": style_images_dir,
        "output_img_dir": output_img_dir,
        "img_format": img_format,
    }

    results_path = neural_style_transfer(optimization_config)
    return results_path

def visualize_style_transfer(content_image, style_image, results_path):
    """
    Показывает: контент, результат, стиль.
    """
    if len(os.listdir(results_path)) == 0:
        print("Результат не был сохранён.")
        return

    plt.figure(figsize=(13, 4))
    folders = [
        "content-images/",
        "output-images/" + Path(results_path).name + "/",
        "style-images/",
    ]
    combined_image = f"{Path(content_image).stem}_{Path(style_image).stem}.jpg"
    files = [content_image, combined_image, style_image]
    titles = ["Контент", "Результат", "Стиль"]

    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.imshow(plt.imread("data/" + folders[i] + files[i]))
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])

    plt.tight_layout()
    plt.show()
# Out:
# Cloning into 'Neural-Style-Transfer'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 379 (delta 72), reused 105 (delta 34), pack-reused 225 (from 1)
# Receiving objects: 100% (379/379), 92.21 MiB | 54.52 MiB/s, done.
# Resolving deltas: 100% (143/143), done.
# /content/Neural-Style-Transfer

# %% [markdown]
# Для тех же пар изображений контест-стиль попытайтесь сгенерировать картинку с таким контекстом и стилем с помощью диффузионной модели, рассмотренной на семинаре, задав нужный промпт.

# %%
...

# %% [markdown]
# **Вывод:**

# %% [markdown]
# ...

# %% [markdown]
# ---
# © 2026 команда <a href="https://thetahat.ru/">ThetaHat</a> для ВвАД
